# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque

# %%
G = nx.Graph()
G.add_edge('A', 'B')
G.add_edge('B', 'C')
G.add_edge('B', 'D')
print(G.adj)

nx.draw(G, pos=nx.circular_layout(G), node_color='r', edge_color='b')   # default spring_layout
# Out:
# {'A': {'B': {}}, 'B': {'A': {}, 'C': {}, 'D': {}}, 'C': {'B': {}}, 'D': {'B': {}}}
