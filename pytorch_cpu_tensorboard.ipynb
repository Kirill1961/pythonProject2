# %%
import torch
import time
from torch.utils.tensorboard import SummaryWriter

# %%
# ЯВНО указываем CPU
device = torch.device("cpu")

# Создаём тензор
x = torch.tensor([1.0, 2.0, 3.0]).to(device)

# Простая операция
y = x * 2

print("x:", x)
print("y:", y)
print("Устройство x:", x.device)
print("Устройство y:", y.device)
# Out:
# x: tensor([1., 2., 3.])
# y: tensor([2., 4., 6.])
# Устройство x: cpu
# Устройство y: cpu

# %%
device = torch.device("cpu")

x = torch.randn(3000, 3000).to(device)
start = time.time()

y = torch.matmul(x, x)

end = time.time()

print("Устройство:", y.device)
print("Время (сек):", round(end - start, 3))
# Out:
# Устройство: cpu
# Время (сек): 0.158

# %% [markdown]
# # tensorboard

# %% [markdown]
# **Запуск TensorBoard в терминале PyCharm**
# * `tensorboard --logdir runs`
#
# или в **ячейке** jupiter
#
# * `%load_ext tensorboard`
# * `%tensorboard --logdir runs`
#
#     * НЕ вводим ничего в терминал
#     * Открываем браузер
#     * Переходим в браузер по адресу: http://localhost:6006
#     * CTRL+C - закрыть tensorboard

# %%
# TODO Папка с логами
writer = SummaryWriter(log_dir="runs/exp1")

# %%
for epoch in range(10):
    train_loss = 1 / (epoch + 1)
    val_loss = train_loss + 0.1

    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val", val_loss, epoch)

# %%
writer.close()

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 16508), started 0:01:29 ago. (Use '!kill 16508' to kill it.)
#       <iframe id="tensorboard-frame-f2f914484ba3d878" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f2f914484ba3d878");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
