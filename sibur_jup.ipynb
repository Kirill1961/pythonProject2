# %%
import numpy as np
import pandas as pd

# %%
# TODO data

data = pd.read_csv('D:\Eduson_data\sample_submission.csv')

data['timestamp'] = pd.to_datetime(data['timestamp'])  # трансформ признака из str в timestamp

data.set_index('timestamp', inplace=True)  # трансформ Признака timestamp в Индекс timestamp

data.sort_index(inplace=True) # Сортируем для перестраховки

df = data.iloc[0: 5, :]  # For Train

data[data.index.day == 9]

type(data.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
